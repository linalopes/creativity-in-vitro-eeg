# %%
from pathlib import Path
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# MNE
import mne
from mne.preprocessing import ICA
from mne_icalabel import label_components

# Feature Engineering
from scipy.signal import welch
import pywt
from scipy.stats import kurtosis, skew

# Machine Learning
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
import torch
print(torch.__version__)
print("MPS available?", torch.backends.mps.is_available())
# Out:
# 2.7.1
# MPS available? True

# %% [markdown]
# ### Config — paths & processing constants
#
# All hard-coded parameters live in one place so you (or a colleague) can
# re-run the notebook on another machine by editing a single cell.
#
# * **paths** – BIDS root and sub-folders inside `derivatives/`
# * **data**  – recording constants reused later (montage, sfreq, etc.)
# * **ica**   – method & hyper-params; change here to compare algorithms
# * **reject** – thresholds that tag bad ICs automatically
# * **features** – what spectral bands & window length to extract
# * **model** – a first classifier + CV split; purely exploratory

# %%
CONFIG = dict(

    # ---------- paths ----------------------------------------------------
    paths = dict(
        bids_root   = Path("../bids_dataset"),
        deriv_root  = Path("../bids_dataset/derivatives"),
        filt_dir    = Path('../bids_dataset/derivatives/filt_crop/sub-01/ses-second/eeg/'),
        ica_dir     = Path("../bids_dataset/derivatives/ica_clean/sub-01/ses-second/eeg/"),
        # feat_dir    = Path("../bids_dataset/derivatives/features"),
        annot_dir   = Path("../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/"),
        timing_csv  = Path("../audio-timeline.csv"),
    ),

    # ---------- recording constants --------------------------------------
    data = dict(
        sfreq       = 125.0,                      # Hz
        eeg_ch      = ["Fp1","Fp2","C3","C4","T7","T8",
                       "O1","O2","F3","F4","Fz","Pz","P3","P4"],
        montage     = "standard_1020",
        n_blocks    = 21,
    ),

    # ---------- ICA parameters -------------------------------------------
    ica = dict(
        method         = "picard",    # "fastica" | "picard" | "infomax"
        n_components   = 0.99,        # keep 99 % of variance
        random_state   = 42,
        max_iter       = 500,
        decim          = 2            # 125 Hz → 62.5 Hz for fitting
    ),

    # ---------- auto-reject thresholds (z-score in IC space) -------------
    reject = dict(
        eog_z     = 3.0,     # eye blinks
        emg_z     = 3.0,     # muscle
        slow_z    = 3.0      # slow drifts
    ),

    # ---------- feature extraction ---------------------------------------
    features = dict(
        bands   = {"delta":(1,4), "theta":(4,8),
                   "alpha":(8,13), "beta":(13,30),
                   "gamma":(30,45)},
        win_sec       = 2.0,   # sliding-window length
        step_sec      = 0.5,
        wavelet_levels = 6
    ),

    # ---------- first classifier to prototype ----------------------------
    model = dict(
        clf          = "lightgbm",   # or "svm"
        cv_folds     = 5,
        test_size    = 0.2
    ),
)

# ------------------------------------------------------------------------
# create sub-folders if they don’t exist
for p in CONFIG["paths"].values():
    if p.suffix == "":          # skip the CSV path; only create dirs
        p.mkdir(parents=True, exist_ok=True)

print("Config updated – paths for annotations and timeline CSV added 🚀")
# Out:
# Config updated – paths for annotations and timeline CSV added 🚀

# %% [markdown]
# ## 1. Loading the 21 filtered & cropped blocks
#
# Before any additional processing we first bring the twenty pre-filtered /
# cropped recordings into memory.
# At this stage **projectors remain OFF** so the data are identical to the files
# written by 04_Lina_restart_with_MNE (`*_flt-crop_raw.fif`).

# %%
# Gather the expected *_desc-filtcrop_eeg.fif files (BIDS-compliant)
filt_dir = CONFIG["paths"]["filt_dir"]

blk_paths = sorted(filt_dir.glob("sub-01_ses-second_task-musicphrases_run-*_desc-filtcrop_eeg.fif"))
assert len(blk_paths) == CONFIG["data"]["n_blocks"], (
    f"Expected {CONFIG['data']['n_blocks']} blocks, found {len(blk_paths)}."
)

raw_blocks = []
for fpath in blk_paths:
    print(f"Reading {fpath.name} …", end=" ")
    raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
    raw_blocks.append(raw)
    print("✓")

print(f"\nLoaded {len(raw_blocks)} blocks. Projectors are currently OFF.")
# Out:
# Reading sub-01_ses-second_task-musicphrases_run-01_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-02_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-03_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-04_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-05_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-06_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-07_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-08_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-09_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-10_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-11_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-12_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-13_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-14_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-15_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-16_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-17_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-18_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-19_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-20_desc-filtcrop_eeg.fif … ✓
# Reading sub-01_ses-second_task-musicphrases_run-21_desc-filtcrop_eeg.fif … ✓
#
# Loaded 21 blocks. Projectors are currently OFF.

# %% [markdown]
# ### 1a · Why we switch **ON** the average-reference projection
#
# Each `.fif` block already contains a *projector* that re-references the data to
# the **common average** (CAR).  Up to this point we kept that projector **OFF**
# to ensure the raw voltages from the previous notebook were preserved during
# filtering/cropping.  Turning the projector **ON** now is critical for three
# reasons:
#
# 1. **Signal centring**
#    Referencing every channel to the grand mean neutralises slow offsets caused
#    by unequal electrode impedances or amplifier drift.  This flattens the
#    baseline and yields cleaner butterfly plots and topomaps.
#
# 2. **Better ICA decomposition**
#    ICA assumes that sources mix *linearly* and with zero-mean time courses.
#    Applying the CAR before decomposition improves the separation of ocular,
#    cardiac and myogenic components, making automatic IC labelling more
#    reliable.
#
# 3. **Pipeline consistency**
#    Most EEG-to-text decoding papers perform ICA on average-referenced data.
#    Activating the projector now keeps our workflow aligned with that
#    literature and prevents accidental mixing of referenced and
#    non-referenced epochs later on.
#
# > **Note:** `raw.apply_proj()` is *idempotent*—once the projector is applied,
# > calling it again will have no additional effect as the projection matrix is
# > removed from `raw.info["projs"]`.

# %%
for idx, raw in enumerate(raw_blocks):
    if not raw.info["projs"]:
        raise RuntimeError(f"Block {idx:02d} has no projector defined.")
    raw.apply_proj(verbose=False)

print(f"✅  Average-reference projection applied to {len(raw_blocks)} blocks.")
# Out:
# ✅  Average-reference projection applied to 21 blocks.

# %% [markdown]
# #### Where does the stored **common-average reference (CAR)** come from?
#
# The projector you see inside each `Raw` file was created in the previous notebook (the
# pre-processing stage) with the following single line of MNE-Python:
#
# ```python
# raw.set_eeg_reference("average", projection=True)
# ````
#
# **Why defer application?**
#
# Filtering, notch removal, and cropping were performed on the original voltage
# scale to avoid numerical artefacts that can arise when the reference itself is
# filtered. By postponing the CAR we ensure it touches the already-cleaned
# signal only once, making the operation idempotent.
#
# So, the CAR originates entirely from this offline MNE call—nothing was changed
# on the OpenBCI Cyton hardware during acquisition. The headset’s built-in bias
# drive delivered a common electrode reference while recording; the average
# reference we apply now is purely a software construct saved inside each
# .fif file.

# %% [markdown]
# ## 2. ICA cleaning with Picard and automatic component rejection
#
# With all blocks now average-referenced, the next step is to remove ocular,
# muscular, cardiac, and line-noise artefacts via **Independent Component
# Analysis (ICA)**.  We adopt the following design:
#
# | Choice | Value | Rationale |
# |--------|-------|-----------|
# | *Algorithm* | **Picard** (`method="picard"`) | Fast and deterministic when seeded, converges reliably on small channel counts. |
# | *Number of components* | `n_components = 0.99` | Keep enough PCs to explain ≥ 99 % variance while discarding tiny noise dimensions. |
# | *Sample thinning* | `decim = 2` (training at ~62.5 Hz) | Avoids aliasing of our 1–45 Hz pass-band and gives ~2× speed-up over full-rate fitting. |
# | *Auto-labelling* | `mne_icalabel` if available; fallback to `find_bads_eog/muscle` with z-scores in `CONFIG["reject"]` | Fully reproducible; manual tweaks can follow in the QA report. |
# | *Output files* | Cleaned `Raw`  → `ica_clean/blk##_icaclean_raw.fif`<br>ICA object → `ica_clean/blk##_ica.fif` | Keeps both the processed data and the unmixing matrix for later inspection. |
#
# The cleaned signals will still be stored at the **original 125 Hz**, because
# the unmixing matrix learned on the thinned data is applied to the full-rate
# recordings.

# %%
for raw in raw_blocks:
    assert raw.proj     , "CAR not applied?"
    assert raw.info['sfreq'] == 125.0, "Unexpected sampling rate!"

print("✅  Sanity check passed for all blocks.")
# Out:
# ✅  Sanity check passed for all blocks.

# %% [markdown]
# ### Why we fit **one ICA per block** instead of concatenating all 20 blocks
#
# | Argument | Details |
# |-----------|---------|
# | **1 — Temporal stationarity** | ICA assumes that sources and their mixing matrix stay *constant* during the data used for fitting.  Each block is only ≈ 133 s; across 47 min the participant’s posture, electrode impedance, or low-level muscle tone can drift, breaking the stationarity assumption.  By fitting block-wise we give Picard data that better meet its mathematical requirements. |
# | **2 — Transient artefacts** | Some artefacts (e.g. a coughing bout, jaw clench) may appear in just one or two blocks.  Concatenating would spread those components’ influence across the global unmixing matrix, making them harder to isolate or causing “ghost” ICs in clean segments.  Per-block fitting localises the fix to where the artefact actually occurs. |
# | **3 — Memory & speed** | 47 min × 14 ch × 125 Hz ≈ 490 000 samples.  Even with `decim=2`, a single global ICA would hold > 200 kB of data in memory during optimisation and take several times longer to converge.  Twenty small ICAs (7–9 comps each) finish in a few seconds per block and can be parallelised if desired. |
# | **4 — Easier re-processing** | If a block later shows unexpected noise, we can re-fit ICA *only for that block* without touching the other 19 clean ones.  This keeps the pipeline modular and speeds up iterations. |
# | **5 — Simplicity for downstream QA** | Each `blk##_ica.fif` carries its own component labels.  The QA report can display “before/after” figures alongside the block’s lyrics slice, making inspection intuitive. |
#
#
# > *Trade-off:* concatenating could, in theory, yield slightly better separation of **persistent** artefacts (e.g. ECG) by giving ICA more samples.  In practice the benefits rarely outweigh the non-stationarity risk for long, naturalistic EEG sessions like ours.

# %%
# Load the filtered and cropped run-01 block
fif_path = CONFIG["paths"]["filt_dir"] / "sub-01_ses-second_task-musicphrases_run-01_desc-filtcrop_eeg.fif"
raw = mne.io.read_raw_fif(fif_path, preload=True, verbose=False)

# Apply common average reference if needed
raw.apply_proj()

# Run ICA without label_components()
ica = mne.preprocessing.ICA(
    n_components=CONFIG["ica"]["n_components"],
    method=CONFIG["ica"]["method"],
    random_state=CONFIG["ica"]["random_state"],
    max_iter=CONFIG["ica"]["max_iter"],
    fit_params=dict(ortho=False, extended=True),
)

ica.fit(raw, decim=CONFIG["ica"]["decim"], verbose="error")

# Plot ICA components for visual inspection
ica.plot_components(title="ICA components — run-01");
# Out:
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# <MNEFigure size 975x496 with 10 Axes>

# %%
#ica.plot_sources(raw, show_scrollbars=True, title="ICA source signals — run-01")

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.25.2

# %%
# Setup
ica_dir = CONFIG["paths"]["ica_dir"]
filt_dir = CONFIG["paths"]["filt_dir"]
THRESH = 0.80
KEYWORDS = ("eye", "muscle", "heart", "line")  # artefact classes do ICLabel

# Lista de arquivos filtrados (igual ao notebook)
filt_paths = sorted(filt_dir.glob("sub-01_ses-second_task-musicphrases_run-*_desc-filtcrop_eeg.fif"))

# Escolher o primeiro bloco
raw = raw_blocks[0]
in_path = filt_paths[0]
stem = Path(in_path).stem.replace("_desc-filtcrop_eeg", "")
print(f"\n### Block {stem}: fitting ICA ...")

raw.apply_proj()

ica = mne.preprocessing.ICA(
    n_components=CONFIG["ica"]["n_components"],
    method=CONFIG["ica"]["method"],
    random_state=CONFIG["ica"]["random_state"],
    max_iter=CONFIG["ica"]["max_iter"],
    fit_params=dict(ortho=False, extended=True),
)
ica.fit(raw, decim=CONFIG["ica"]["decim"], verbose="error")

try:
    out = label_components(raw, ica, method="iclabel")
    labels = out["labels"]
    proba = np.asanyarray(out["y_pred_proba"])

    exclude_idx = []
    for i, lab in enumerate(labels):
        p = proba[i] if proba.ndim == 1 else proba[i].max()
        if any(kw in lab.lower() for kw in KEYWORDS) and p >= THRESH:
            exclude_idx.append(i)

    print(f"    ICLabel → excluding {exclude_idx}")

    if exclude_idx:
        ica.plot_components(picks=exclude_idx, title=f"{stem} – rejected ICs", show=True)

    ica.exclude = exclude_idx
    ica.apply(raw)
    raw.save(ica_dir / f"{stem}_desc-icaclean_eeg.fif", overwrite=True, verbose=False)
    ica.save(ica_dir / f"{stem}_ica.fif", overwrite=True, verbose=False)

except Exception as e:
    print(f"❌ Erro ao rodar ICLabel: {e}")
# Out:
# ### Block sub-01_ses-second_task-musicphrases_run-01: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/1300955462.py:28: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/1300955462.py:28: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0, 8]
# <MNEFigure size 390x260.5 with 2 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 14 PCA components

# %%
# --- 1. Directory and parameter setup ---
ica_dir = CONFIG["paths"]["ica_dir"]
filt_dir = CONFIG["paths"]["filt_dir"]
THRESH = 0.80
KEYWORDS = ("eye", "muscle", "heart", "line")  # ICLabel artifact classes

# --- 2. List of filtered files ---
filt_paths = sorted(filt_dir.glob("sub-01_ses-second_task-musicphrases_run-*_desc-filtcrop_eeg.fif"))


# --- 4. Loop through filtered blocks ---
for raw, in_path in zip(raw_blocks, filt_paths):
    stem = Path(in_path).stem.replace("_desc-filtcrop_eeg", "")
    print(f"\n### Block {stem}: fitting ICA ...")

    raw.apply_proj()  # ensure CAR is on

    ica = mne.preprocessing.ICA(
        n_components=CONFIG["ica"]["n_components"],
        method=CONFIG["ica"]["method"],
        random_state=CONFIG["ica"]["random_state"],
        max_iter=CONFIG["ica"]["max_iter"],
        fit_params=dict(ortho=False, extended=True),
    )
    ica.fit(raw, decim=CONFIG["ica"]["decim"], verbose="error")

    # --- 5. Run ICLabel with timeout/fallback ---
    exclude_idx = []

    try:
        out = label_components(raw, ica, method="iclabel")
        labels = out["labels"]
        proba = np.asanyarray(out["y_pred_proba"])

        for i, lab in enumerate(labels):
            p = proba[i] if proba.ndim == 1 else proba[i].max()
            if any(kw in lab.lower() for kw in KEYWORDS) and p >= THRESH:
                exclude_idx.append(i)

        print(f"    ICLabel → excluding {exclude_idx}")

    except TimeoutError:
        print("⚠️ ICLabel skipped due to timeout.")
    except Exception as e:
        print(f"⚠️ ICLabel failed: {e}")

    # --- 6. Apply and save ICA (always) ---
    ica.exclude = exclude_idx
    if exclude_idx:
        ica.plot_components(picks=exclude_idx,
                            title=f"{stem} – rejected ICs", show=True)

    ica.apply(raw)

    raw.save(ica_dir / f"{stem}_desc-icaclean_eeg.fif", overwrite=True, verbose=False)
    ica.save(ica_dir / f"{stem}_ica.fif", overwrite=True, verbose=False)

print("\n✅ ICA finished — all blocks labeled and saved (even clean ones).")
# Out:
# ### Block sub-01_ses-second_task-musicphrases_run-01: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding []
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (9 components)
#     Zeroing out 0 ICA components
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-02: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0, 8]
# <MNEFigure size 390x260.5 with 2 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-03: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0]
# <MNEFigure size 195x260.5 with 1 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 1 ICA component
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-04: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0]
# <MNEFigure size 195x260.5 with 1 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 1 ICA component
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-05: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0]
# <MNEFigure size 195x260.5 with 1 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 1 ICA component
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-06: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0]
# <MNEFigure size 195x260.5 with 1 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 1 ICA component
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-07: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0, 8]
# <MNEFigure size 390x260.5 with 2 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-08: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0, 7]
# <MNEFigure size 390x260.5 with 2 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-09: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0, 7]
# <MNEFigure size 390x260.5 with 2 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-10: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0, 8]
# <MNEFigure size 390x260.5 with 2 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-11: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0]
# <MNEFigure size 195x260.5 with 1 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 1 ICA component
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-12: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0, 8]
# <MNEFigure size 390x260.5 with 2 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-13: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [9]
# <MNEFigure size 195x260.5 with 1 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 1 ICA component
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-14: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0, 8]
# <MNEFigure size 390x260.5 with 2 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-15: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0, 8]
# <MNEFigure size 390x260.5 with 2 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-16: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0]
# <MNEFigure size 195x260.5 with 1 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 1 ICA component
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-17: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [1]
# <MNEFigure size 195x260.5 with 1 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 1 ICA component
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-18: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0, 9]
# <MNEFigure size 390x260.5 with 2 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-19: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0]
# <MNEFigure size 195x260.5 with 1 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 1 ICA component
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-20: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0, 7]
# <MNEFigure size 390x260.5 with 2 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 2 ICA components
#     Projecting back using 14 PCA components
#
# ### Block sub-01_ses-second_task-musicphrases_run-21: fitting ICA ...
# Projections have already been applied. Setting proj attribute to True.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_20821/3264404828.py:31: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   out = label_components(raw, ica, method="iclabel")
#     ICLabel → excluding [0]
# <MNEFigure size 195x260.5 with 1 Axes>
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 1 ICA component
#     Projecting back using 14 PCA components
#
# ✅ ICA finished — all blocks labeled and saved (even clean ones).

# %% [markdown]
# ## 3. Inspection of ICA results (example: blk18)
#
# Below we reload both the fitted **ICA model** and the corresponding
# **cleaned Raw** for *blk18* (the penultimate block) and:
#
# 1. Print a textual summary of which ICs were excluded and their labels.
# 2. Display the topomaps of the rejected components and the “before vs after”
#    butterfly plot so we can verify that eye / muscle artefacts are gone.

# %%
blk_idx = 18
run_str = f"run-{blk_idx+1:02d}"
stem = f"sub-01_ses-second_task-musicphrases_{run_str}"
ica_path = CONFIG["paths"]["ica_dir"] / f"{stem}_ica.fif"
raw_path = CONFIG["paths"]["ica_dir"] / f"{stem}_desc-icaclean_eeg.fif"

ica  = mne.preprocessing.read_ica(ica_path)
raw  = mne.io.read_raw_fif(raw_path, preload=True)  # just to know ch-names

print(f"=== {stem}  ICA summary ===")
print("Excluded IC indices :", ica.exclude)
try:
    print("ICLabel classes   :", ica.labels_)  # added by label_components
except AttributeError:
    print("No 'labels_' attr → ICLabel not run / not saved.")

print(f"Cleaned Raw shape  : {raw._data.shape}  (n_ch × n_samples)")
# Out:
# Reading /Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/ica_clean/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-19_ica.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 14) active
# Now restoring ICA solution ...
# Ready.
# Opening raw data file ../bids_dataset/derivatives/ica_clean/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-19_desc-icaclean_eeg.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 14) active
#     Range : 3257 ... 19882 =     26.056 ...   159.056 secs
# Ready.
# Reading 0 ... 16625  =      0.000 ...   133.000 secs...
# === sub-01_ses-second_task-musicphrases_run-19  ICA summary ===
# Excluded IC indices : [0]
# ICLabel classes   : {'brain': [1, 2, 3, 4, 5, 6, 8], 'muscle': [], 'eog': [0, 7], 'ecg': [], 'line_noise': [9], 'ch_noise': [], 'other': []}
# Cleaned Raw shape  : (15, 16626)  (n_ch × n_samples)

# %%
# Visual sanity checks for run-19 (idx = 18)

# Use the same stem as previous cell
blk_idx = 18
run_str = f"run-{blk_idx+1:02d}"
stem = f"sub-01_ses-second_task-musicphrases_{run_str}"

# 1. Topomaps of rejected ICs
if ica.exclude:
    ica.plot_components(picks=ica.exclude,
                        title=f"{stem} – rejected ICs",
                        show=True)

# 2. Butterfly plots before vs. after ICA application
# Load original filtered/cropped (not ICA-cleaned yet)
orig_path = CONFIG["paths"]["filt_dir"] / f"{stem}_desc-filtcrop_eeg.fif"
raw_orig  = mne.io.read_raw_fif(orig_path, preload=True)

# Use the same visual scaling for before/after
scale = dict(eeg=2e-6)  # 2 µV/div, as previously defined

fig1 = raw_orig.plot(title=f"{stem} – BEFORE ICA  (2 µV/div)",
                     scalings=scale, show=True)

fig2 = ica.apply(raw_orig.copy(), exclude=ica.exclude)\
          .plot(title=f"{stem} – AFTER ICA  (2 µV/div)",
                scalings=scale, show=True)

plt.show()
# Out:
# <MNEFigure size 195x260.5 with 1 Axes>
# Opening raw data file ../bids_dataset/derivatives/filt_crop/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-19_desc-filtcrop_eeg.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 14)  idle
#     Range : 3257 ... 19882 =     26.056 ...   159.056 secs
# Ready.
# Reading 0 ... 16625  =      0.000 ...   133.000 secs...
# Using pyopengl with version 3.1.9
# Applying ICA to Raw instance
#     Applying projection operator with 1 vector (pre-whitener application)
#     Transforming to ICA space (10 components)
#     Zeroing out 1 ICA component
#     Projecting back using 14 PCA components
# Using pyopengl with version 3.1.9
# Channels marked as bad:
# none
# Channels marked as bad:
# none

# %% [markdown]
# ## 4. Injecting phrase targets as MNE Annotations
#
# **Why here?**
# After ICA cleaning, we now mark the six lyrical phrases in each block
# (`phrase 0–6`) as **MNE Annotations**, preserving:
#
# * the structure of the song,
# * alignment to audio onsets,
# * and a consistent marker format for epoching or modeling.
#
# **How the annotations are derived**
# We use `audio-timeline.csv`, which contains three repetitions (`sequence1–3`)
# of the full song. Each row is a phrase (0–6), and each column is its end time
# within a sequence. Since all filtered blocks are already cropped to start at
# **sequence 1 (t = 0)** and last exactly **133 seconds**, we can align directly.
#
# **Annotation strategy**
#
# - `phrase/0` marks the *intro melody*
# - `phrase/1–6` mark the six lyrical segments
# - The annotations are stored directly inside the `.fif` and saved to
#   `derivatives/annotated/..._annot_raw.fif`

# %%
# Measure the duration of each ICA-cleaned block
durations = []

for f in sorted(CONFIG["paths"]["ica_dir"].glob("sub-01_ses-second_task-musicphrases_run-??_desc-icaclean_eeg.fif")):
    blk_id = f.stem[:5]
    raw    = mne.io.read_raw_fif(f, preload=False, verbose=False)
    dur_s  = raw.times[-1]
    durations.append({"block": blk_id, "seconds": round(dur_s, 2)})

df = pd.DataFrame(durations)
print(df.to_string(index=False))

print("\nSummary:")
print(df["seconds"].describe().to_string())
# Out:
# block  seconds
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
# sub-0    133.0
#
# Summary:
# count     21.0
# mean     133.0
# std        0.0
# min      133.0
# 25%      133.0
# 50%      133.0
# 75%      133.0
# max      133.0

# %%
# ⏱️ Annotate clean blocks with phrases 0–6 (safe version)

TMAX = 133.0  # max block duration
tl = pd.read_csv(CONFIG["paths"]["timing_csv"])

def hms2s(t):  # convert HH:MM:SS to seconds
    h, m, s = [float(x) for x in t.split(":")]
    return 3600 * h + 60 * m + s

# Convert all timeline values to seconds
for col in tl.columns[1:]:
    tl[col] = tl[col].apply(hms2s)

# phrase_end_times[phrase][sequence] = time (s)
phrase_end_times = {int(r["target"]): r[1:].tolist() for _, r in tl.iterrows()}

in_dir  = CONFIG["paths"]["ica_dir"]
out_dir = CONFIG["paths"]["annot_dir"]
out_dir.mkdir(parents=True, exist_ok=True)

fpaths = sorted(in_dir.glob("sub-01_ses-second_task-musicphrases_run-*_desc-icaclean_eeg.fif"))

for f_in in fpaths:
    stem = f_in.stem.replace("_desc-icaclean_eeg", "")
    raw = mne.io.read_raw_fif(f_in, preload=True, verbose=False)

    print(f"\n📄 Processing: {stem}")
    print("📌 Before:", raw.annotations)

    # Safely clear previous state
    raw.set_annotations(None)
    raw.set_meas_date(None)
    raw.crop(tmin=0.0, tmax=TMAX, include_tmax=True)

    # Create fresh annotations for this file
    ann = mne.Annotations(onset=[], duration=[], description=[])

    for seq in range(3):         # three repetitions
        for p in range(7):       # phrases 0–6
            # Onset = end of previous phrase (or 0.0 at beginning)
            if p == 0:
                onset = phrase_end_times[6][seq - 1] if seq > 0 else 0.0
            else:
                onset = phrase_end_times[p - 1][seq]

            end = phrase_end_times[p][seq]
            duration = end - onset

            # Check if annotation fits within block
            if onset >= raw.times[-1] or end > raw.times[-1]:
                print(f"⚠️ Skipped phrase/{p} in seq {seq}: outside of range ({onset:.2f} → {end:.2f})")
                continue

            ann.append(onset=onset, duration=duration, description=f"phrase/{p}")
            print(f"📝 phrase/{p} | seq {seq} | {onset:.2f}s → {end:.2f}s")

    raw.set_annotations(ann)
    print("✅ After:", raw.annotations)

    out_path = out_dir / f"{stem}_icaclean_annot.fif"
    raw.save(out_path, overwrite=True, verbose=False)

    print(f"💾 Saved: {out_path.name} — {len(ann)} annotations (last onset: {ann.onset[-1]:.2f}s)")

print("\n🎯 Finished — All annotations now correctly bounded by TMAX.")
# Out:
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-01
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-01_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-02
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-03
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-03_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-04
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-04_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-05
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-05_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-06
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-06_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-07
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-07_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-08
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-08_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-09
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-09_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-10
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-10_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-11
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-11_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-12
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-12_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-13
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-13_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-14
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-14_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-15
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-15_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-16
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-01_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-03_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-04_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-05_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-06_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-07_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-08_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-09_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-10_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-11_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-12_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-13_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-14_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-15_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-16_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-16_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-17
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-17_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-18
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-18_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-19
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-19_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-20
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-20_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 📄 Processing: sub-01_ses-second_task-musicphrases_run-21
# 📌 Before: <Annotations | 0 segments>
# 📝 phrase/0 | seq 0 | 0.00s → 5.00s
# 📝 phrase/1 | seq 0 | 5.00s → 10.00s
# 📝 phrase/2 | seq 0 | 10.00s → 16.00s
# 📝 phrase/3 | seq 0 | 16.00s → 23.00s
# 📝 phrase/4 | seq 0 | 23.00s → 29.00s
# 📝 phrase/5 | seq 0 | 29.00s → 35.00s
# 📝 phrase/6 | seq 0 | 35.00s → 43.00s
# 📝 phrase/0 | seq 1 | 43.00s → 49.00s
# 📝 phrase/1 | seq 1 | 49.00s → 54.00s
# 📝 phrase/2 | seq 1 | 54.00s → 60.00s
# 📝 phrase/3 | seq 1 | 60.00s → 67.00s
# 📝 phrase/4 | seq 1 | 67.00s → 73.00s
# 📝 phrase/5 | seq 1 | 73.00s → 79.00s
# 📝 phrase/6 | seq 1 | 79.00s → 87.00s
# 📝 phrase/0 | seq 2 | 87.00s → 93.00s
# 📝 phrase/1 | seq 2 | 93.00s → 99.00s
# 📝 phrase/2 | seq 2 | 99.00s → 105.00s
# 📝 phrase/3 | seq 2 | 105.00s → 112.00s
# 📝 phrase/4 | seq 2 | 112.00s → 118.00s
# 📝 phrase/5 | seq 2 | 118.00s → 124.00s
# 📝 phrase/6 | seq 2 | 124.00s → 132.00s
# ✅ After: <Annotations | 21 segments: phrase/0 (3), phrase/1 (3), phrase/2 (3), ...>
# 💾 Saved: sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif — 21 annotations (last onset: 124.00s)
#
# 🎯 Finished — All annotations now correctly bounded by TMAX.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-17_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-18_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-19_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-20_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1599794733.py:61: RuntimeWarning: This filename (/Users/linalopes/Desktop/creativity-in-vitro-eeg/notebooks/../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(out_path, overwrite=True, verbose=False)

# %%
from mne.io import read_raw_fif
from pathlib import Path

# Get directory containing annotations
annot_dir = CONFIG["paths"]["annot_dir"]
# Find all ICA-cleaned annotation files
fpaths = sorted(annot_dir.glob("*_icaclean_annot.fif"))

# Process each file
for fpath in fpaths:
    # Load the raw data and annotations
    raw = read_raw_fif(fpath, preload=True, verbose=False)
    ann = raw.annotations

    # Skip files with no annotations
    if len(ann) == 0:
        print(f"⚠️ {fpath.name} — no annotations")
        continue

    # Get details of first annotation
    first_onset = ann.onset[0]
    first_duration = ann.duration[0]
    first_desc = ann.description[0]
    first_end = first_onset + first_duration

    # Get details of last annotation
    last_onset = ann.onset[-1]
    last_duration = ann.duration[-1]
    last_desc = ann.description[-1]
    last_end = last_onset + last_duration

    # Get total signal duration
    total_time = raw.times[-1]

    # Print summary information
    print(f"\n🧠 {fpath.name}")
    print(f"🟢 First:  onset={first_onset:.2f}s  duration={first_duration:.2f}s  → end={first_end:.2f}s | label={first_desc}")
    print(f"🔴 Last:   onset={last_onset:.2f}s  duration={last_duration:.2f}s  → end={last_end:.2f}s | label={last_desc}")
    print(f"📏 Total annotations: {len(ann)} | Signal duration: {total_time:.2f}s")

    # Check if annotations exceed signal duration
    if last_end > total_time:
        print(f"❌ OVERFLOW: annotation ends at {last_end:.2f}s (beyond {total_time:.2f}s)")
    else:
        print("✅ OK — annotations within bounds")
# Out:
# 🧠 sub-01_ses-second_task-musicphrases_run-01_icaclean_annot.fif
# 🟢 First:  onset=25.55s  duration=5.00s  → end=30.55s | label=phrase/0
# 🔴 Last:   onset=149.55s  duration=8.00s  → end=157.55s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 157.55s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif
# 🟢 First:  onset=22.86s  duration=5.00s  → end=27.86s | label=phrase/0
# 🔴 Last:   onset=146.86s  duration=8.00s  → end=154.86s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 154.86s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-03_icaclean_annot.fif
# 🟢 First:  onset=30.66s  duration=5.00s  → end=35.66s | label=phrase/0
# 🔴 Last:   onset=154.66s  duration=8.00s  → end=162.66s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 162.66s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-04_icaclean_annot.fif
# 🟢 First:  onset=26.12s  duration=5.00s  → end=31.12s | label=phrase/0
# 🔴 Last:   onset=150.12s  duration=8.00s  → end=158.12s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 158.12s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-05_icaclean_annot.fif
# 🟢 First:  onset=26.94s  duration=5.00s  → end=31.94s | label=phrase/0
# 🔴 Last:   onset=150.94s  duration=8.00s  → end=158.94s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 158.94s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-06_icaclean_annot.fif
# 🟢 First:  onset=16.17s  duration=5.00s  → end=21.17s | label=phrase/0
# 🔴 Last:   onset=140.17s  duration=8.00s  → end=148.17s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 148.17s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-07_icaclean_annot.fif
# 🟢 First:  onset=25.95s  duration=5.00s  → end=30.95s | label=phrase/0
# 🔴 Last:   onset=149.95s  duration=8.00s  → end=157.95s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 157.95s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-08_icaclean_annot.fif
# 🟢 First:  onset=28.82s  duration=5.00s  → end=33.82s | label=phrase/0
# 🔴 Last:   onset=152.82s  duration=8.00s  → end=160.82s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 160.82s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-09_icaclean_annot.fif
# 🟢 First:  onset=34.20s  duration=5.00s  → end=39.20s | label=phrase/0
# 🔴 Last:   onset=158.20s  duration=8.00s  → end=166.20s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 166.20s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-10_icaclean_annot.fif
# 🟢 First:  onset=15.82s  duration=5.00s  → end=20.82s | label=phrase/0
# 🔴 Last:   onset=139.82s  duration=8.00s  → end=147.82s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 147.82s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-11_icaclean_annot.fif
# 🟢 First:  onset=19.29s  duration=5.00s  → end=24.29s | label=phrase/0
# 🔴 Last:   onset=143.29s  duration=8.00s  → end=151.29s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 151.29s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-12_icaclean_annot.fif
# 🟢 First:  onset=33.66s  duration=5.00s  → end=38.66s | label=phrase/0
# 🔴 Last:   onset=157.66s  duration=8.00s  → end=165.66s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 165.66s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-13_icaclean_annot.fif
# 🟢 First:  onset=27.76s  duration=5.00s  → end=32.76s | label=phrase/0
# 🔴 Last:   onset=151.76s  duration=8.00s  → end=159.76s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 159.76s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-14_icaclean_annot.fif
# 🟢 First:  onset=29.26s  duration=5.00s  → end=34.26s | label=phrase/0
# 🔴 Last:   onset=153.26s  duration=8.00s  → end=161.26s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 161.26s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-15_icaclean_annot.fif
# 🟢 First:  onset=27.85s  duration=5.00s  → end=32.85s | label=phrase/0
# 🔴 Last:   onset=151.85s  duration=8.00s  → end=159.85s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 159.85s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-16_icaclean_annot.fif
# 🟢 First:  onset=20.72s  duration=5.00s  → end=25.72s | label=phrase/0
# 🔴 Last:   onset=144.72s  duration=8.00s  → end=152.72s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 152.72s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-17_icaclean_annot.fif
# 🟢 First:  onset=26.30s  duration=5.00s  → end=31.30s | label=phrase/0
# 🔴 Last:   onset=150.30s  duration=8.00s  → end=158.30s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 158.30s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-18_icaclean_annot.fif
# 🟢 First:  onset=27.20s  duration=5.00s  → end=32.20s | label=phrase/0
# 🔴 Last:   onset=151.20s  duration=8.00s  → end=159.20s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 159.20s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-19_icaclean_annot.fif
# 🟢 First:  onset=26.06s  duration=5.00s  → end=31.06s | label=phrase/0
# 🔴 Last:   onset=150.06s  duration=8.00s  → end=158.06s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 158.06s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-20_icaclean_annot.fif
# 🟢 First:  onset=25.87s  duration=5.00s  → end=30.87s | label=phrase/0
# 🔴 Last:   onset=149.87s  duration=8.00s  → end=157.87s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 157.87s (beyond 133.00s)
#
# 🧠 sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif
# 🟢 First:  onset=36.86s  duration=5.00s  → end=41.86s | label=phrase/0
# 🔴 Last:   onset=160.86s  duration=8.00s  → end=168.86s | label=phrase/6
# 📏 Total annotations: 21 | Signal duration: 133.00s
# ❌ OVERFLOW: annotation ends at 168.86s (beyond 133.00s)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-01_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-03_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-04_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-05_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-06_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-07_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-08_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-09_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-10_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-11_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-12_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-13_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-14_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-15_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-16_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-17_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-18_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-19_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-20_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1552503694.py:8: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)

# %%
# load an already annotated block
raw = mne.io.read_raw_fif(
    CONFIG["paths"]["annot_dir"] / "sub-01_ses-second_task-musicphrases_run-01_icaclean_annot.fif", preload=False)

# scale of 10 µV/div, starts at t=0 s, shows 30 s per screen
raw.plot(title="blk02 – annotations overlay",
         start=0, duration=30,
         scalings=dict(eeg=2e-6),
         block=True)     # pause cell until window is closed
# Out:
# Opening raw data file ../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-01_icaclean_annot.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 14) active
#     Range : 3194 ... 19819 =     25.552 ...   158.552 secs
# Ready.
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1258190046.py:2: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-01_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(
# Using qt as 2D backend.
# Using pyopengl with version 3.1.9
# Channels marked as bad:
# none

# %% [markdown]
# ## 5

# %%
# 📍 Etapa 5.1 — Similaridade entre repetições da mesma frase em um mesmo bloco

from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
import mne
import numpy as np
from collections import defaultdict

# 📁 Escolha o bloco que deseja analisar
run = 1  # Altere para o número do run desejado
fpath = sorted(CONFIG["paths"]["annot_dir"].glob(f"*run-{run:02d}*_annot.fif"))[0]
raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
print(f"🎧 Analisando: {fpath.name}")
print(f"🧠 EEG shape: {raw.get_data(picks='eeg').shape} | Duração: {raw.times[-1]:.2f}s")

# 🎯 Inicializa dicionário de vetores por frase
rep_vectors = defaultdict(list)

# 🔍 Itera pelas anotações e extrai média temporal por canal
for ann in raw.annotations:
    phrase = ann['description']
    tmin = ann['onset'] - raw.annotations.onset[0]
    tmax = tmin + ann['duration']
    try:
        data = raw.copy().crop(tmin, tmax).get_data(picks="eeg")  # shape: (n_channels, n_times)
        vec = data.mean(axis=1)  # média ao longo do tempo → shape: (n_channels,)
        rep_vectors[phrase].append(vec)
    except Exception as e:
        print(f"⚠️ Falha ao extrair {phrase} @ {tmin:.2f}s → {tmax:.2f}s: {e}")

# 📦 Verifica quantos vetores foram extraídos por frase
for phrase, vecs in rep_vectors.items():
    print(f"{phrase}: {len(vecs)} vetores")

# 📊 Plota matriz de similaridade para cada frase com 3 repetições
fig, axes = plt.subplots(1, len(rep_vectors), figsize=(3 * len(rep_vectors), 3))

if len(rep_vectors) == 1:
    axes = [axes]

for ax, (phrase, vecs) in zip(axes, sorted(rep_vectors.items())):
    if len(vecs) != 3:
        ax.axis("off")
        ax.set_title(f"{phrase} (incompleto)")
        continue
    sims = cosine_similarity(vecs)
    sns.heatmap(sims, annot=True, vmin=0, vmax=1, square=True, cbar=False, ax=ax,
                cmap="YlOrBr", xticklabels=False, yticklabels=False)
    ax.set_title(f"{phrase}")

fig.suptitle(f"🔍 Similaridade entre repetições das frases — run {run:02d}", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3790516463.py:13: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-01_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# 🎧 Analisando: sub-01_ses-second_task-musicphrases_run-01_icaclean_annot.fif
# 🧠 EEG shape: (14, 16626) | Duração: 133.00s
# phrase/0: 3 vetores
# phrase/1: 3 vetores
# phrase/2: 3 vetores
# phrase/3: 3 vetores
# phrase/4: 3 vetores
# phrase/5: 3 vetores
# phrase/6: 3 vetores
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3790516463.py:53: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import mne

# Caminho dos dados
annot_dir = CONFIG["paths"]["annot_dir"]
fpaths = sorted(annot_dir.glob("*run-*_icaclean_annot.fif"))

# Frases que vamos considerar
phrases = [f"phrase/{i}" for i in range(7)]

# Layout do grid de plots
n_cols = 7
n_rows = len(fpaths)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(3.5*n_cols, 2*n_rows))
fig.suptitle("🔁 Similaridade entre repetições — todos os runs", fontsize=16)
fig.subplots_adjust(top=0.95, hspace=0.6)

for row_idx, fpath in enumerate(fpaths):
    run_name = fpath.stem.split("_")[-1]  # ex: run-01
    raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
    raw.set_meas_date(None)
    data = raw.get_data(picks="eeg")
    annotations = raw.annotations

    phrase_vectors = {}

    for ann in annotations:
        label = ann["description"]
        if label not in phrases:
            continue
        tmin = ann['onset'] - raw.annotations.onset[0]
        tmax = tmin + ann['duration']

        try:
            crop = raw.copy().crop(tmin, tmax)
            vec = crop.get_data(picks="eeg").mean(axis=1)
            phrase_vectors.setdefault(label, []).append(vec)
        except Exception as e:
            print(f"⚠️ {run_name} — {label}: erro ao extrair → {e}")

    for col_idx, phrase in enumerate(phrases):
        ax = axes[row_idx, col_idx] if n_rows > 1 else axes[col_idx]
        vecs = phrase_vectors.get(phrase, [])

        if len(vecs) == 3:
            sim = cosine_similarity(vecs)
            sns.heatmap(sim, vmin=-1, vmax=1, cmap="YlOrBr", annot=True, fmt=".2f", cbar=False, ax=ax)
        else:
            ax.text(0.5, 0.5, f"{phrase}\n(incompleto)", fontsize=9,
                    va="center", ha="center")
            ax.set_xticks([])
            ax.set_yticks([])

        ax.set_title(f"{phrase}", fontsize=10)
        ax.set_xlabel("")
        ax.set_ylabel("")

    # Label do lado esquerdo de cada linha
    axes[row_idx, 0].set_ylabel(run_name, fontsize=11, rotation=0, labelpad=50)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-01_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-03_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-04_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-05_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-06_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-07_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-08_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-09_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-10_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-11_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-12_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-13_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-14_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-15_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-16_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-17_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-18_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-19_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-20_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/820387991.py:24: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/seaborn/utils.py:61: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /opt/homebrew/Caskroom/miniforge/base/envs/creativity-eeg/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict
import numpy as np
import mne

# 🧾 Armazena os resultados no dicionário final (mas imprime formatado)
all_similarities = {}

# 🌀 Itera sobre os 21 blocos (runs)
for run in range(1, 22):
    run_key = f"run{run:02d}"
    all_similarities[run_key] = {}

    fpath = sorted(CONFIG["paths"]["annot_dir"].glob(f"*run-{run:02d}*_annot.fif"))[0]
    raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
    eeg = raw.get_data(picks="eeg")

    # Inicializa dicionário de vetores por frase
    rep_vectors = defaultdict(list)

    for ann in raw.annotations:
        phrase = ann["description"]
        tmin = ann["onset"] - raw.annotations.onset[0]
        tmax = tmin + ann["duration"]
        try:
            data = raw.copy().crop(tmin, tmax).get_data(picks="eeg")
            vec = data.mean(axis=1)
            rep_vectors[phrase].append(vec)
        except Exception as e:
            continue

    print(f"\n🧠 {run_key}")
    for phrase in sorted(rep_vectors):
        vecs = rep_vectors[phrase]
        if len(vecs) == 3:
            sims = cosine_similarity(vecs)
            all_similarities[run_key][phrase] = sims.tolist()
            sim_vals = [round(sims[i, j], 2) for i in range(3) for j in range(i+1, 3)]
            print(f"  {phrase}: {sim_vals}")
        else:
            all_similarities[run_key][phrase] = None
            print(f"  {phrase}: ❌ incompleto ({len(vecs)} vetores)")
# Out:
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-01_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-03_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-04_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-05_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-06_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# 🧠 run01
#   phrase/0: [0.44, -0.79, -0.5]
#   phrase/1: [0.2, -0.15, -0.75]
#   phrase/2: [0.26, -0.62, 0.49]
#   phrase/3: [-0.67, 0.3, -0.55]
#   phrase/4: [-0.8, 0.63, -0.48]
#   phrase/5: [-0.93, 0.85, -0.87]
#   phrase/6: [-0.24, -0.18, -0.52]
#
# 🧠 run02
#   phrase/0: [0.27, 0.24, 0.52]
#   phrase/1: [0.11, -0.07, -0.26]
#   phrase/2: [0.45, 0.51, 0.36]
#   phrase/3: [-0.21, -0.13, -0.11]
#   phrase/4: [-0.34, 0.41, 0.2]
#   phrase/5: [-0.46, 0.09, 0.06]
#   phrase/6: [-0.21, -0.27, -0.67]
#
# 🧠 run03
#   phrase/0: [0.01, 0.21, 0.37]
#   phrase/1: [0.62, -0.53, -0.56]
#   phrase/2: [-0.01, -0.35, -0.19]
#   phrase/3: [0.85, -0.55, -0.75]
#   phrase/4: [0.8, -0.12, 0.1]
#   phrase/5: [-0.06, 0.02, 0.24]
#   phrase/6: [0.37, 0.21, 0.67]
#
# 🧠 run04
#   phrase/0: [0.86, -0.39, -0.16]
#   phrase/1: [0.89, -0.22, -0.32]
#   phrase/2: [0.01, 0.33, -0.36]
#   phrase/3: [-0.39, -0.75, 0.55]
#   phrase/4: [0.25, -0.76, 0.26]
#   phrase/5: [0.64, -0.7, -0.2]
#   phrase/6: [0.44, -0.34, 0.24]
#
# 🧠 run05
#   phrase/0: [0.52, 0.72, 0.68]
#   phrase/1: [0.35, 0.52, -0.18]
#   phrase/2: [0.48, -0.21, -0.01]
#   phrase/3: [-0.02, -0.2, -0.59]
#   phrase/4: [-0.15, -0.36, -0.02]
#   phrase/5: [-0.06, -0.35, -0.26]
#   phrase/6: [0.64, 0.68, 0.27]
#
# 🧠 run06
#   phrase/0: [0.82, -0.32, -0.02]
#   phrase/1: [0.38, -0.31, -0.41]
#   phrase/2: [0.57, 0.52, 0.61]
#   phrase/3: [-0.35, 0.32, 0.37]
#   phrase/4: [0.11, 0.46, -0.05]
#   phrase/5: [0.4, 0.19, -0.53]
#   phrase/6: [0.12, -0.07, 0.24]
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-07_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-08_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-09_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-10_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-11_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-12_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# 🧠 run07
#   phrase/0: [0.05, -0.06, -0.18]
#   phrase/1: [-0.3, -0.63, 0.7]
#   phrase/2: [0.4, 0.6, 0.49]
#   phrase/3: [-0.05, -0.13, 0.1]
#   phrase/4: [-0.28, 0.11, -0.54]
#   phrase/5: [-0.34, 0.29, -0.26]
#   phrase/6: [0.49, -0.04, 0.56]
#
# 🧠 run08
#   phrase/0: [0.52, 0.5, 0.62]
#   phrase/1: [-0.7, 0.66, -0.87]
#   phrase/2: [-0.16, -0.73, 0.3]
#   phrase/3: [-0.8, -0.4, 0.79]
#   phrase/4: [-0.36, 0.06, -0.36]
#   phrase/5: [0.2, 0.1, 0.57]
#   phrase/6: [0.35, -0.43, -0.08]
#
# 🧠 run09
#   phrase/0: [-0.83, 0.9, -0.88]
#   phrase/1: [-0.18, 0.48, 0.13]
#   phrase/2: [-0.29, -0.13, 0.56]
#   phrase/3: [0.43, 0.93, 0.26]
#   phrase/4: [-0.71, -0.58, 0.02]
#   phrase/5: [0.4, -0.63, -0.36]
#   phrase/6: [-0.76, -0.72, 0.38]
#
# 🧠 run10
#   phrase/0: [-0.02, 0.13, 0.18]
#   phrase/1: [-0.19, 0.65, -0.14]
#   phrase/2: [-0.77, -0.32, -0.03]
#   phrase/3: [-0.37, -0.69, 0.54]
#   phrase/4: [-0.34, 0.48, 0.13]
#   phrase/5: [0.68, 0.46, 0.26]
#   phrase/6: [0.77, 0.22, -0.02]
#
# 🧠 run11
#   phrase/0: [-0.43, -0.55, 0.73]
#   phrase/1: [-0.28, 0.21, 0.35]
#   phrase/2: [0.79, -0.05, 0.07]
#   phrase/3: [0.82, 0.76, 0.58]
#   phrase/4: [-0.03, 0.08, -0.47]
#   phrase/5: [0.38, -0.2, -0.75]
#   phrase/6: [-0.34, -0.1, 0.53]
#
# 🧠 run12
#   phrase/0: [0.39, 0.81, 0.69]
#   phrase/1: [-0.45, 0.53, -0.62]
#   phrase/2: [-0.22, -0.51, -0.31]
#   phrase/3: [0.44, 0.11, -0.59]
#   phrase/4: [-0.17, 0.67, -0.28]
#   phrase/5: [-0.64, 0.57, -0.29]
#   phrase/6: [0.56, -0.57, -0.2]
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-13_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-14_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-15_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-16_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-17_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-18_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# 🧠 run13
#   phrase/0: [-0.54, -0.2, -0.06]
#   phrase/1: [-0.24, 0.21, -0.22]
#   phrase/2: [-0.38, -0.07, 0.67]
#   phrase/3: [0.11, 0.07, -0.83]
#   phrase/4: [-0.42, 0.08, 0.25]
#   phrase/5: [-0.18, -0.04, 0.56]
#   phrase/6: [0.26, 0.11, 0.23]
#
# 🧠 run14
#   phrase/0: [0.13, 0.53, -0.34]
#   phrase/1: [-0.23, 0.08, -0.44]
#   phrase/2: [-0.07, -0.06, -0.63]
#   phrase/3: [-0.58, 0.15, 0.27]
#   phrase/4: [0.33, 0.36, 0.67]
#   phrase/5: [0.41, -0.39, -0.75]
#   phrase/6: [0.76, -0.36, 0.17]
#
# 🧠 run15
#   phrase/0: [0.45, 0.29, -0.31]
#   phrase/1: [-0.11, -0.27, 0.59]
#   phrase/2: [0.33, -0.68, -0.78]
#   phrase/3: [-0.69, 0.72, -0.54]
#   phrase/4: [0.03, 0.88, -0.07]
#   phrase/5: [-0.47, 0.87, -0.37]
#   phrase/6: [-0.47, -0.55, -0.1]
#
# 🧠 run16
#   phrase/0: [0.01, 0.19, 0.2]
#   phrase/1: [-0.02, 0.24, -0.55]
#   phrase/2: [0.85, 0.01, 0.25]
#   phrase/3: [-0.45, 0.1, 0.06]
#   phrase/4: [0.53, -0.39, 0.08]
#   phrase/5: [0.21, -0.26, -0.07]
#   phrase/6: [-0.76, 0.0, -0.34]
#
# 🧠 run17
#   phrase/0: [0.55, 0.26, 0.58]
#   phrase/1: [-0.03, -0.48, 0.27]
#   phrase/2: [-0.44, -0.63, 0.06]
#   phrase/3: [-0.16, 0.26, 0.15]
#   phrase/4: [0.73, 0.5, 0.21]
#   phrase/5: [-0.17, -0.1, 0.11]
#   phrase/6: [-0.13, 0.51, -0.26]
#
# 🧠 run18
#   phrase/0: [-0.38, 0.36, -0.6]
#   phrase/1: [0.7, -0.24, -0.12]
#   phrase/2: [-0.03, -0.54, 0.27]
#   phrase/3: [0.56, 0.26, -0.39]
#   phrase/4: [0.85, 0.38, 0.16]
#   phrase/5: [0.64, -0.81, -0.75]
#   phrase/6: [0.41, -0.87, -0.52]
#
# 🧠 run19
#   phrase/0: [-0.18, -0.59, -0.09]
#   phrase/1: [-0.15, -0.2, 0.06]
#   phrase/2: [0.15, 0.35, -0.07]
#   phrase/3: [-0.93, 0.88, -0.81]
#   phrase/4: [0.02, 0.47, 0.2]
#   phrase/5: [-0.43, 0.44, -0.64]
#   phrase/6: [0.55, 0.8, 0.34]
#
# 🧠 run20
#   phrase/0: [-0.11, -0.44, 0.57]
#   phrase/1: [0.28, -0.25, 0.74]
#   phrase/2: [-0.24, -0.57, 0.58]
#   phrase/3: [0.36, 0.5, -0.19]
#   phrase/4: [0.59, -0.78, -0.31]
#   phrase/5: [-0.8, -0.43, 0.43]
#   phrase/6: [-0.31, 0.1, 0.35]
#
# 🧠 run21
#   phrase/0: [0.45, 0.54, 0.66]
#   phrase/1: [0.58, 0.38, 0.63]
#   phrase/2: [0.62, 0.78, 0.81]
#   phrase/3: [-0.44, -0.1, 0.65]
#   phrase/4: [-0.01, -0.85, 0.01]
#   phrase/5: [-0.31, -0.4, -0.21]
#   phrase/6: [0.03, 0.55, -0.34]
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-19_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-20_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3172489301.py:15: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True, verbose=False)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### 🧠 Análise de Similaridade por Bloco (run01 → run21)
#
# Esta seção apresenta uma análise qualitativa dos padrões de similaridade entre repetições da mesma frase dentro de cada bloco. A avaliação se baseia na inspeção das matrizes de similaridade obtidas via `cosine_similarity` dos vetores médios por canal para cada frase (phrase/0 até phrase/6).
#
# ---
#
# ### 🧾 Observações Gerais por Bloco:
#
# - **run01:** Frases com baixa consistência; especialmente phrase/5 e phrase/6 mostram padrões opostos entre repetições.
# - **run02:** Padrões mais suaves; phrase/2 foi mais consistente, enquanto phrase/6 teve maior variação.
# - **run03:** Alta variação em phrases 1–3; phrase/3 apresentou oposição entre repetições.
# - **run04:** Frases 0 e 1 foram altamente consistentes. A partir da phrase/3 houve instabilidade.
# - **run05:** Um dos blocos mais estáveis. Frases 0, 1, 6 com alta similaridade.
# - **run06:** Frases 0, 2 e 3 bastante consistentes. phrase/5 apresentou maior variabilidade.
# - **run07:** phrase/2 com excelente consistência. phrase/1 com inversão entre repetições.
# - **run08:** Alta variabilidade em phrase/1 e phrase/3. phrase/0 e phrase/5 mais estáveis.
# - **run09:** phrase/3 mostrou alta similaridade entre repetições. phrase/0 e phrase/4 com oposição marcante.
# - **run10:** phrase/5 muito consistente. phrase/2 com padrão oposto nas repetições.
# - **run11:** phrase/3 com consistência elevada. phrase/5 teve inversão forte entre as repetições.
# - **run12:** phrase/0 e phrase/4 bem estáveis. phrase/6 com padrão divergente entre repetições.
# - **run13:** Frases 2, 5 e 6 relativamente estáveis. phrase/3 com oscilação extrema.
# - **run14:** phrase/4 foi a mais estável. phrase/5 e phrase/6 mostram direções opostas.
# - **run15:** Frases 1 e 4 com padrões bem definidos. phrase/3 instável.
# - **run16:** phrase/2 consistente. phrase/6 apresentou inversão clara de padrão.
# - **run17:** phrase/0 e phrase/4 muito próximas entre si. phrase/2 bastante ruidosa.
# - **run18:** phrase/4 bem coerente entre repetições. phrase/5 com instabilidade acentuada.
# - **run19:** phrase/3 teve oposição forte entre repetições. phrase/6 consistente.
# - **run20:** phrase/1 e phrase/6 estáveis. phrase/5 apresentou oposição.
# - **run21:** phrase/2 extremamente consistente. phrase/4 com oposição visível entre repetições.
#
# ---
#
# ### ⚠️ Nota sobre o Design Experimental
#
# A variabilidade observada nas repetições da mesma frase pode estar parcialmente relacionada ao design do experimento:
#
# - A tarefa consistia em **ouvir a música com os olhos fechados** e **"cantar mentalmente"** junto, repetindo o estímulo 21 vezes.
# - Essa é uma tarefa **altamente dependente de atenção, memória auditiva e controle interno de tempo**, sem feedback externo.
# - Fatores como **fadiga, lapsos de atenção**, mudança de foco (melodia vs. letra), ou variação emocional entre repetições podem ter influenciado os padrões cerebrais registrados.
# - Como consequência, **a resposta neural à mesma frase nem sempre foi consistente**, refletindo tanto a oscilação natural do estado mental quanto o custo cognitivo do próprio design da tarefa.
#
# ---

# %%
def phrase_stats(raw, n_samples=250):
    from collections import defaultdict
    phrase_data = defaultdict(list)
    sfreq = raw.info['sfreq']

    for onset, duration, desc in zip(raw.annotations.onset,
                                     raw.annotations.duration,
                                     raw.annotations.description):
        if desc.startswith("phrase/"):
            phrase = desc.split("/")[1]
            stop = onset + duration
            if stop > raw.times[-1]:
                continue
            segment = raw.copy().crop(tmin=onset, tmax=stop).get_data(picks="eeg")
            current = segment.shape[1]
            if current > n_samples:
                segment = segment[:, :n_samples]
            elif current < n_samples:
                pad = np.zeros((segment.shape[0], n_samples - current))
                segment = np.concatenate([segment, pad], axis=1)
            phrase_data[phrase].append(segment)

    # Statistics per phrase
    stats = {}
    for phrase, segments in phrase_data.items():
        arr = np.stack(segments)  # (n_seq, n_ch, n_time)
        mean = arr.mean()
        std  = arr.std()
        vmin = arr.min()
        vmax = arr.max()
        stats[phrase] = dict(mean=mean, std=std, min=vmin, max=vmax)

    return stats

# --- Use in blocks 2 and 21 (remember: Python index starts at 0)
raw1  = read_raw_fif(CONFIG["paths"]["annot_dir"] / "sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif", preload=True)
raw21 = read_raw_fif(CONFIG["paths"]["annot_dir"] / "sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif", preload=True)

stats1 = phrase_stats(raw1)
stats21 = phrase_stats(raw21)

# --- Print comparison
import pandas as pd

df = pd.DataFrame.from_dict(stats1, orient='index')
df.columns = [f"{col}_run02" for col in df.columns]

df2 = pd.DataFrame.from_dict(stats21, orient='index')
df2.columns = [f"{col}_run21" for col in df2.columns]

comparison = pd.concat([df, df2], axis=1)
display(comparison)
# Out:
# Opening raw data file ../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 14) active
#     Range : 2857 ... 19482 =     22.856 ...   155.856 secs
# Ready.
# Reading 0 ... 16625  =      0.000 ...   133.000 secs...
# Opening raw data file ../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 14) active
#     Range : 4608 ... 21233 =     36.864 ...   169.864 secs
# Ready.
# Reading 0 ... 16625  =      0.000 ...   133.000 secs...
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3861523696.py:36: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw1  = read_raw_fif(CONFIG["paths"]["annot_dir"] / "sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif", preload=True)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3861523696.py:37: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw21 = read_raw_fif(CONFIG["paths"]["annot_dir"] / "sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif", preload=True)
#      mean_run02     std_run02     min_run02     max_run02    mean_run21  \
# 0 -3.017302e-17  1.306206e-07 -6.335961e-07  7.605856e-07 -5.358933e-18
# 1 -9.136706e-18  1.295263e-07 -7.849999e-07  6.421369e-07 -5.158200e-17
# 2 -1.024106e-18  1.284844e-07 -7.944491e-07  6.217285e-07 -3.077449e-17
# 3 -3.819700e-17  1.034524e-07 -7.461102e-07  4.053747e-07  3.532170e-17
# 4 -8.835566e-17  1.675406e-07 -9.161259e-07  9.248550e-07 -6.786523e-17
# 5 -2.635987e-17  1.284491e-07 -6.444419e-07  7.305109e-07 -1.046973e-16
# 6 -3.436735e-17  1.296122e-07 -7.625231e-07  5.100598e-07  6.356423e-17
#
#       std_run21     min_run21     max_run21
# 0  1.219168e-07 -6.597899e-07  4.868334e-07
# 1  1.299105e-07 -8.383084e-07  6.164892e-07
# 2  1.374628e-07 -8.329507e-07  7.373010e-07
# 3  1.375078e-07 -8.320098e-07  7.092051e-07
# 4  1.340707e-07 -7.940459e-07  6.220253e-07
# 5  1.419439e-07 -6.913525e-07  6.320677e-07
# 6  1.297325e-07 -7.731458e-07  5.315301e-07

# %%
from mne.io import read_raw_fif
from mne.viz import plot_topomap
import numpy as np
import matplotlib.pyplot as plt

# --- Caminho base ---
paths = CONFIG["paths"]["annot_dir"]

# --- Blocos escolhidos ---
files = {
    "run02": paths / "sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif",
    "run21": paths / "sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif"
}

# --- Frases a comparar ---
target_phrases = ["phrase/2", "phrase/6"]

# --- Função para média por canal de todas ocorrências da frase ---
def compute_phrase_topo(raw, phrase):
    picks = raw.copy().pick("eeg")
    data_list = []

    for ann in raw.annotations:
        if ann["description"] == phrase:
            tmin = ann["onset"]
            tmax = min(tmin + ann["duration"], raw.times[-1])
            if tmax > tmin:
                cropped = picks.copy().crop(tmin=tmin, tmax=tmax)
                data = cropped.get_data()
                data_list.append(data.mean(axis=1))  # média por canal

    if not data_list:
        return None

    return np.mean(data_list, axis=0)

# --- Processamento e plot ---
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 6))
fig.suptitle("Topografia média — phrase/2 vs phrase/6", fontsize=14)

for col, (run_label, fpath) in enumerate(files.items()):
    raw = read_raw_fif(fpath, preload=True, verbose=False)

    for row, phrase in enumerate(target_phrases):
        topo = compute_phrase_topo(raw, phrase)

        if topo is not None:
            plot_topomap(
                topo, raw.info, axes=axes[row, col],
                show=False, contours=0, sphere=0.09
            )
            axes[row, col].set_title(f"{run_label} — {phrase}")
        else:
            axes[row, col].text(0.5, 0.5, "no data", ha="center", va="center")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3420654058.py:42: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/3420654058.py:42: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_fif(fpath, preload=True, verbose=False)

# %%
from sklearn.preprocessing import normalize

# Coletar vetores topográficos para todas as frases de um bloco
def get_topo_vectors(raw, phrases):
    vectors = {}
    for phrase in phrases:
        vec = compute_phrase_topo(raw, phrase)
        if vec is not None:
            vectors[phrase] = normalize(vec.reshape(1, -1), norm="l2")[0]  # normaliza L2
    return vectors

# Carregar os dois blocos
raws = {
    run_label: read_raw_fif(fpath, preload=True, verbose=False)
    for run_label, fpath in files.items()
}

# Aplicar para frases 0 a 6
phrases = [f"phrase/{i}" for i in range(7)]
vectors_per_run = {
    run_label: get_topo_vectors(raw, phrases)
    for run_label, raw in raws.items()
}
# Out:
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1275927181.py:14: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-02_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   run_label: read_raw_fif(fpath, preload=True, verbose=False)
# /var/folders/ny/tk1xvwsn7n11pkl0vlgl1sz80000gn/T/ipykernel_29549/1275927181.py:14: RuntimeWarning: This filename (../bids_dataset/derivatives/annotated/sub-01/ses-second/eeg/sub-01_ses-second_task-musicphrases_run-21_icaclean_annot.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   run_label: read_raw_fif(fpath, preload=True, verbose=False)

# %%
import pandas as pd

# Criar matriz frase_i (run02) vs frase_j (run21)
sim_matrix = pd.DataFrame(index=phrases, columns=phrases)

for p1 in phrases:
    for p2 in phrases:
        v1 = vectors_per_run["run02"].get(p1)
        v2 = vectors_per_run["run21"].get(p2)
        if v1 is not None and v2 is not None:
            sim_matrix.loc[p1, p2] = np.dot(v1, v2)
        else:
            sim_matrix.loc[p1, p2] = np.nan

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(sim_matrix.astype(float), annot=True, cmap="coolwarm", vmin=0, vmax=1)
plt.title("Similaridade Coseno — Frases run02 × run21 (topografia)")
plt.xlabel("Frases em run21")
plt.ylabel("Frases em run02")
plt.tight_layout()
plt.show()
