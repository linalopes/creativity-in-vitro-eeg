# %%
from pathlib import Path
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
CONFIG = {
    'fif_dir' : Path('../bids_dataset/derivatives/filt_crop/sub-01/ses-second/eeg/'),
    'ch_order': [
        'Fp1', 'Fp2', 'C3', 'C4', 'T3', 'T4',
        'O1',  'O2',  'F3', 'F4', 'Fz', 'Pz',
        'P3',  'P4'
    ]
}
